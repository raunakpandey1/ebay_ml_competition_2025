# %% [markdown]
# # Convert to BIOES

# %%
import pandas as pd
df_train1 = pd.read_csv('Tagged_Titles_Train.tsv', keep_default_na=False, na_values=None, sep="\t")

df_train1['Title'] = df_train1['Title'].str.replace(r'\s{2,}', ' ', regex=True)
df_train1['Title'] = df_train1['Title'].str.replace('\xa0', ' ', regex=True)

# %%
df_train1
# Out:
#        Record Number  Category  \
# 0                  1         2
# 1                  1         2
# 2                  1         2
# 3                  1         2
# 4                  1         2
# ...              ...       ...
# 56807           5000         2
# 56808           5000         2
# 56809           5000         2
# 56810           5000         2
# 56811           5000         2
#
#                                                    Title    Token  \
# 0      MINI 1.6 W10B16A W11B16A R50 Steuerkettensatz ...     MINI
# 1      MINI 1.6 W10B16A W11B16A R50 Steuerkettensatz ...      1.6
# 2      MINI 1.6 W10B16A W11B16A R50 Steuerkettensatz ...  W10B16A
# 3      MINI 1.6 W10B16A W11B16A R50 Steuerkettensatz ...  W11B16A
# 4      MINI 1.6 W10B16A W11B16A R50 Steuerkettensatz ...      R50
# ...                                                  ...      ...
# 56807  BOSCH Zahnriemen + Rollensatz + MEYLE Wasserpu...     Opel
# 56808  BOSCH Zahnriemen + Rollensatz + MEYLE Wasserpu...     Saab
# 56809  BOSCH Zahnriemen + Rollensatz + MEYLE Wasserpu...      1.8
# 56810  BOSCH Zahnriemen + Rollensatz + MEYLE Wasserpu...        /
# 56811  BOSCH Zahnriemen + Rollensatz + MEYLE Wasserpu...      1.8
#
#                                Tag
# 0        Kompatible_Fahrzeug_Marke
# 1      Kompatibles_Fahrzeug_Modell
# 2                 Herstellernummer
# 3
# 4
# ...                            ...
# 56807    Kompatible_Fahrzeug_Marke
# 56808  Kompatibles_Fahrzeug_Modell
# 56809
# 56810                            O
# 56811  Kompatibles_Fahrzeug_Modell
#
# [56812 rows x 5 columns]

# %%
def label_entity1(tokens, label, category, title):
    n = len(tokens)
    if n == 1:
        return [(tokens[0][0], category, title, tokens[0][1], f"S-{label}", tokens[0][2])]
    else:
        labeled = []
        for i, (rec, token, orig_idx) in enumerate(tokens):
            if i == 0:
                tag = f"B-{label}"
            elif i == n - 1:
                tag = f"E-{label}"
            else:
                tag = f"I-{label}"
            labeled.append((rec, category, title, token, tag, orig_idx))
        return labeled

def convert_df_to_bioes1(df):
    result_rows = []

    # Save original dtypes
    original_dtypes = df.dtypes.to_dict()

    # Save original index
    df = df.reset_index()  # creates a new column with original index
    df = df.rename(columns={"index": "OrigIndex"})

    for record_id, group in df.groupby("Record Number"):
        group = group.reset_index(drop=True)
        current_entity = []
        current_label = None
        current_category = None
        current_title = None

        for idx, row in group.iterrows():
            token = row['Token']
            tag = row['Tag']
            category = row['Category']
            title = row['Title']
            orig_idx = row['OrigIndex']

            if tag == 'O':
                if current_entity:
                    result_rows.extend(label_entity1(current_entity, current_label, current_category, current_title))
                    current_entity = []
                    current_label = None
                    current_category = None
                    current_title = None
                result_rows.append((record_id, category, title, token, 'O', orig_idx))

            elif pd.notna(tag) and tag != '':
                if current_entity:
                    result_rows.extend(label_entity1(current_entity, current_label, current_category, current_title))
                current_entity = [(record_id, token, orig_idx)]
                current_label = tag
                current_category = category
                current_title = title

            elif pd.isna(tag) or tag == '':
                current_entity.append((record_id, token, orig_idx))

        if current_entity:
            result_rows.extend(label_entity1(current_entity, current_label, current_category, current_title))

    result_df = pd.DataFrame(result_rows, columns=[
        "Record Number", "Category", "Title", "Token", "Tag", "OrigIndex"
    ])

    # Sort by original index and drop the helper column
    result_df = result_df.sort_values(by="OrigIndex").drop(columns=["OrigIndex"]).reset_index(drop=True)

    # Restore original data types carefully:
    for col in ["Record Number", "Category", "Title", "Token", "Tag"]:
        if col in original_dtypes:
            orig_dtype = original_dtypes[col]
            # Check if original dtype is integer
            if pd.api.types.is_integer_dtype(orig_dtype):
                # If the column has any NaNs, use nullable Int64 type; else use original int dtype
                if result_df[col].isnull().any():
                    result_df[col] = result_df[col].astype(pd.Int64Dtype())
                else:
                    result_df[col] = result_df[col].astype(orig_dtype)
            else:
                result_df[col] = result_df[col].astype(orig_dtype)

    return result_df

# %%
BIOES_data = convert_df_to_bioes1(df_train1)

# %%
#4789
df_train1[df_train1['Record Number']==4036]
# Out:
#        Record Number  Category  \
# 45982           4036         2
# 45983           4036         2
# 45984           4036         2
# 45985           4036         2
# 45986           4036         2
# 45987           4036         2
# 45988           4036         2
# 45989           4036         2
# 45990           4036         2
# 45991           4036         2
# 45992           4036         2
#
#                                                    Title           Token  \
# 45982  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...              1x
# 45983  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...     Wasserpumpe
# 45984  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...               +
# 45985  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...  Zahnriemensatz
# 45986  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...             SKF
# 45987  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...            VKMC
# 45988  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...           95624
# 45989  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...         passend
# 45990  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...             für
# 45991  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...            FIAT
# 45992  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...      MITSUBISHI
#
#                              Tag
# 45982       Anzahl_Der_Einheiten
# 45983  Im_Lieferumfang_Enthalten
# 45984                          O
# 45985                 Produktart
# 45986                 Hersteller
# 45987           Herstellernummer
# 45988
# 45989                          O
# 45990                          O
# 45991  Kompatible_Fahrzeug_Marke
# 45992  Kompatible_Fahrzeug_Marke

# %%
BIOES_data[BIOES_data['Record Number']==4036][['Title','Token','Tag']]
# Out:
#                                                    Title           Token  \
# 45982  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...              1x
# 45983  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...     Wasserpumpe
# 45984  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...               +
# 45985  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...  Zahnriemensatz
# 45986  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...             SKF
# 45987  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...            VKMC
# 45988  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...           95624
# 45989  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...         passend
# 45990  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...             für
# 45991  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...            FIAT
# 45992  1x Wasserpumpe + Zahnriemensatz SKF VKMC 95624...      MITSUBISHI
#
#                                Tag
# 45982       S-Anzahl_Der_Einheiten
# 45983  S-Im_Lieferumfang_Enthalten
# 45984                            O
# 45985                 S-Produktart
# 45986                 S-Hersteller
# 45987           B-Herstellernummer
# 45988           E-Herstellernummer
# 45989                            O
# 45990                            O
# 45991  S-Kompatible_Fahrzeug_Marke
# 45992  S-Kompatible_Fahrzeug_Marke

# %%
BIOES_data[BIOES_data['Token']=='AX']
# Out:
#        Record Number  Category  \
# 16528           1449         2
# 19573           1716         2
# 20804           1827      <NA>
# 27251           2399         2
# 49392           4337         2
# 49980           4387         2
# 55420           4877         2
#
#                                                    Title Token  \
# 16528  CONTI Zahnriemen + Rolle Wasserpumpe CITROEN B...    AX
# 19573  BOSCH Zahnriemensatz für CITROEN AX Berlingo X...    AX
# 20804                                               None    AX
# 27251  Zahnriemensatz mit Wasserpumpe Citroen Berling...    AX
# 49392  OEM ZAHNRIEMENSATZ WASSERPUMPE CITROEN AX SAXO...    AX
# 49980  CONTITECH Keilrippenriemen 6PK1564 Citroen Ber...    AX
# 55420  Gates Zahnriemensatz Spannrolle und Wasserpump...    AX
#
#                                  Tag
# 16528  I-Kompatibles_Fahrzeug_Modell
# 19573  S-Kompatibles_Fahrzeug_Modell
# 20804                         S-None
# 27251  E-Kompatibles_Fahrzeug_Modell
# 49392  S-Kompatibles_Fahrzeug_Modell
# 49980  S-Kompatibles_Fahrzeug_Modell
# 55420  S-Kompatibles_Fahrzeug_Modell

# %%
BIOES_data.loc[20804, :] = df_train1.loc[20804, :].copy()
BIOES_data.loc[20804, 'Tag'] = 'S-Kompatibles_Fahrzeug_Modell'
BIOES_data = BIOES_data.astype({
    "Category": "int64"
})

# %%
df1 = df_train1.drop(columns=["Tag"])
df2 = BIOES_data.drop(columns=["Tag"])
df1.equals(df2)
# Out:
# True

# %%
import csv
BIOES_data.to_csv('BIOES_train_data.tsv', sep="\t", index=False, quoting=csv.QUOTE_NONE)
